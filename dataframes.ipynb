# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Name' :['jhon','anna','peter','linda'],
    'Age' :[28,34,29,42],
    'city' :['new york','paris','berlin','london'],
    'salary':[65000,75000,62000,80000]
}
df =pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      city  salary
# 0   jhon   28  new york   65000
# 1   anna   34     paris   75000
# 2  peter   29    berlin   62000
# 3  linda   42    london   80000

# %%
data_list =[
    ['jhon', 28 , 'new york ',65000],
    ['anna',34,'paris',70000],
    ['peter',29,'berlin',62000],
    ['linda',42,'london',80000]
]
df2 = pd.DataFrame(data_list)
columns = ['name','age','city','salary']

# %%
df2 = pd.DataFrame(data_list,columns=columns)
df2
# Out:
#     name  age       city  salary
# 0   jhon   28  new york    65000
# 1   anna   34      paris   70000
# 2  peter   29     berlin   62000
# 3  linda   42     london   80000

# %%
df2[['name','city']]
# Out:
#     name       city
# 0   jhon  new york
# 1   anna      paris
# 2  peter     berlin
# 3  linda     london

# %%
df2['designation'] = ['doctor','eng','doc','eng']
df2
# Out:
#     name  age       city  salary designation
# 0   jhon   28  new york    65000      doctor
# 1   anna   34      paris   70000         eng
# 2  peter   29     berlin   62000         doc
# 3  linda   42     london   80000         eng

# %%
a = df2.drop(['city','salary'],axis = 1)
a
# Out:
#     name  age designation
# 0   jhon   28      doctor
# 1   anna   34         eng
# 2  peter   29         doc
# 3  linda   42         eng

# %%
df2
# Out:
#     name  age       city  salary designation
# 0   jhon   28  new york    65000      doctor
# 1   anna   34      paris   70000         eng
# 2  peter   29     berlin   62000         doc
# 3  linda   42     london   80000         eng

# %%
df2
# Out:
#     name  age       city  salary designation
# 0   jhon   28  new york    65000      doctor
# 1   anna   34      paris   70000         eng
# 2  peter   29     berlin   62000         doc
# 3  linda   42     london   80000         eng

# %%
df2.loc[[0]]
# Out:
#    name  age       city  salary designation
# 0  jhon   28  new york    65000      doctor

# %%
##3 SUBSETS OF A PARTICULAR PORTION ###

df2.iloc[[0, 1]][['city', 'salary']]
# Out:
#         city  salary
# 0  new york    65000
# 1      paris   70000

# %%
df2.loc[[2, 3], ['name', 'age', 'city', 'salary']]
# Out:
#     name  age    city  salary
# 2  peter   29  berlin   62000
# 3  linda   42  london   80000

# %%
df.iloc[3]
# Out:
# Name       linda
# Age           42
# city      london
# salary     80000
# Name: 3, dtype: object

# %%
###CONDITIONAL SELECTION ###

# %%
## only want people with age above 30##

# %%
data = {
    'Name' :['jhon','anna','peter','linda'],
    'Age' :[28,34,29,42],
    'city' :['new york','paris','berlin','london'],
    'salary':[65000,75000,62000,80000]
}
df =pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      city  salary
# 0   jhon   28  new york   65000
# 1   anna   34     paris   75000
# 2  peter   29    berlin   62000
# 3  linda   42    london   80000

# %%
df[(df['Age'] > 30) & (df['city'] == 'paris')]
# Out:
#    Name  Age   city  salary
# 1  anna   34  paris   75000
